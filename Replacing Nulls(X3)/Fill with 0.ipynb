# %%
import pandas as pd
# %load_ext autotime
# Out:
# time: 140 µs (started: 2022-05-09 21:46:14 +04:00)

# %%
filepath = "../Data/TrainDataSample.csv"

train_data = pd.read_csv(filepath)

filepath = "../Data/TestDataSample.csv"

test_data = pd.read_csv(filepath)
# Out:
# time: 2.87 s (started: 2022-05-09 21:46:14 +04:00)

# %%
# Filling missing values by 0s.

train_data = train_data.fillna(0)
test_data = test_data.fillna(0)
# Out:
# time: 264 ms (started: 2022-05-09 21:46:17 +04:00)

# %%
# Concatinating train and test dataframes to check if there are any 0s.

data = pd.concat([train_data, test_data])

Nas = []
count_rows = data.shape[0]
for col in data.columns:
    count_nan = data[col].isna().sum() / count_rows * 100
    Nas.append(count_nan)
NAs_df = pd.DataFrame({'cols':data.columns, 'Nas_perc':Nas})
NAs_df = NAs_df.sort_values(by=['Nas_perc'], ascending=False)
NAs_df
# Out:
#                                               cols  Nas_perc
# 0                       NumberOfOpenBankcardTrades       0.0
# 1                             AnnualPercentageRate       0.0
# 28                                 NumOfChargeOffs       0.0
# 29                                    TermInMonths       0.0
# 30                        AgeOfOldestBankcardTrade       0.0
# 31                               MailType_Standard       0.0
# 32                          PErsonalLoanSumBalance       0.0
# 33                             3MonthFICOAutoDelta       0.0
# 34                       AgeOfOLdestRevolvingTrade       0.0
# 35  Monthlypaymentamountofhighestmortgagetrade_1MO       0.0
# 36             MonthsSinceMostRecentMortgageOpened       0.0
# 37                   NumberOfBankruptciesDismissed       0.0
# 38                                    OfferPayment       0.0
# 39         AgeOfOldestOpenAndCurrentRevolvingTrade       0.0
# 40                                       OfferTerm       0.0
# 41          AggBalToCreditRatioForOpenRetailTrades       0.0
# 42                              NumberOfTradelines       0.0
# 43                            AllLoansPaidAsAgreed       0.0
# 44                       PErsonalLoanSumHighCredit       0.0
# 45                          PErsonalLoanSumPayment       0.0
# 46                                   AutoTradeline       0.0
# 47        KeycodedPresenceOfAFinanceTradeOrInquiry       0.0
# 48                                      TermChange       0.0
# 49                             NumOfMortgageTrades       0.0
# 50                                       Lead Flag       0.0
# 27                           MortgageSumHighCredit       0.0
# 26                        NumberOfInquiries6Months       0.0
# 25             NumberOfNonAutoLoanAndLease12Months       0.0
# 12                                   PaymentChange       0.0
# 2                                    TimesTargeted       0.0
# 3                                          Balance       0.0
# 4                                              Age       0.0
# 5                                     MonthsOnFile       0.0
# 6                                        OfferRate       0.0
# 7                                   SumBalanceAuto       0.0
# 8                                  MonthsSinceOpen       0.0
# 9                                          Payment       0.0
# 10                     AggMonthlyPaymentOpenTrades       0.0
# 11       NumOfTradesOpenedWithin24MosExStudentLoan       0.0
# 13                                 RemainingMonths       0.0
# 24                                  FICO8AutoScore       0.0
# 14                                  SumPaymentAuto       0.0
# 15                    MostRecentOpenedinMonthsAuto       0.0
# 16                                      RateChange       0.0
# 17                    MostRecentClosedinMonthsAuto       0.0
# 18        AggregateBalanceOpenRevolvingNonMortgage       0.0
# 19                    HighestRevolvingCreditAmount       0.0
# 20                     AgeOfMostRecentFinanceTrade       0.0
# 21                  NumberOfBankruptciesDischarged       0.0
# 22                                   FICOAutoScore       0.0
# 23           HighestBankcardSingleBalToCreditRatio       0.0
# 51                                         ZIPCode       0.0
# time: 247 ms (started: 2022-05-09 21:46:18 +04:00)

# %%
# Saving train and test datasets.

train_data.to_csv('../Data/TrainData0.csv', index=False)
test_data.to_csv('../Data/TestData0.csv', index=False)
# Out:
# time: 35.8 s (started: 2022-05-09 21:46:18 +04:00)
